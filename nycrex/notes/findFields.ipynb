# %%
with open ("listings.json", "r") as myfile:
    data = myfile.readlines()

# %%
data
# Out:
# ['[{"listOpenHouse": 4, "listBed": 2.0, "listAmen": "furnished|live_in_super|terrace", "listAvailDate": "2015-10-15T00:00:00-04:00", "listDate": "2015-08-12", "site": "nyc", "userType": "anonymous", "listPropertyType": "multi", "listBrokerage": "winged_foot_companies", "listVideo": 0, "listDaysMarket": 75, "listStatus": "current", "cookie_q_c": 0, "listNabe": "belmont", "listBoro": "bronx", "pageCat": "rentals", "listAgent": "Joseph Clarke", "listBuilding": 341996, "listSqFt": 700, "listPhotos": 6, "listPPSF": 2, "listID": 1608671, "pageType": "show", "listZip": "10458", "listType": "rental", "listGeoLat": 40.8548, "listGeoLon": -73.8855, "listBath": 1.0, "session_q_c": 0, "listNoFee": "true", "listPrice": 1750},\n',
# ...

# %%
import re

# %%
re.findall(", \".+?\":", data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-d634d9f5a7d0> in <module>()
# ----> 1 re.findall(", \".+?\":", data)
#
# /usr/local/Cellar/python/2.7.10_2/Frameworks/Python.framework/Versions/2.7/lib/python2.7/re.pyc in findall(pattern, string, flags)
#     179
#     180     Empty matches are included in the result."""
# --> 181     return _compile(pattern, flags).findall(string)
#     182
#     183 if sys.hexversion >= 0x02020000:
#
# TypeError: expected string or buffer

# %%
type(data)
# Out:
# list

# %%
str(data)
# Out:
# '[\'[{"listOpenHouse": 4, "listBed": 2.0, "listAmen": "furnished|live_in_super|terrace", "listAvailDate": "2015-10-15T00:00:00-04:00", "listDate": "2015-08-12", "site": "nyc", "userType": "anonymous", "listPropertyType": "multi", "listBrokerage": "winged_foot_companies", "listVideo": 0, "listDaysMarket": 75, "listStatus": "current", "cookie_q_c": 0, "listNabe": "belmont", "listBoro": "bronx", "pageCat": "rentals", "listAgent": "Joseph Clarke", "listBuilding": 341996, "listSqFt": 700, "listPhotos": 6, "listPPSF": 2, "listID": 1608671, "pageType": "show", "listZip": "10458", "listType": "rental", "listGeoLat": 40.8548, "listGeoLon": -73.8855, "listBath": 1.0, "session_q_c": 0, "listNoFee": "true", "listPrice": 1750},\\n\', \'{"listOpenHouse": 0, "listBed": 1.0, "listAmen": "fios_available|fios_available|guarantor_ok|pets", "listAvailDate": "2015-11-01T00:00:00-04:00", "listDate": "2015-10-23", "site": "nyc", "userType": "anonymous", "listPropertyType": "rental", "listBrokerage": "bloom
# ...

# %%
data = str(data)

# %%
type(data)
# Out:
# str

# %%
fields = re.findall(", \".+?\":", data)

# %%
fields
# Out:
# [', "listBed":',
#  ', "listAmen":',
#  ', "listAvailDate":',
#  ', "listDate":',
#  ', "site":',
#  ', "userType":',
#  ', "listPropertyType":',
#  ', "listBrokerage":',
#  ', "listVideo":',
#  ', "listDaysMarket":',
#  ', "listStatus":',
#  ', "cookie_q_c":',
#  ', "listNabe":',
#  ', "listBoro":',
#  ', "pageCat":',
#  ', "listAgent":',
#  ', "listBuilding":',
#  ', "listSqFt":',
#  ', "listPhotos":',
#  ', "listPPSF":',
#  ', "listID":',
#  ', "pageType":',
#  ', "listZip":',
#  ', "listType":',
#  ', "listGeoLat":',
#  ', "listGeoLon":',
#  ', "listBath":',
#  ', "session_q_c":',
#  ', "listNoFee":',
#  ', "listPrice":',
#  ', "listBed":',
#  ', "listAmen":',
#  ', "listAvailDate":',
#  ', "listDate":',
#  ', "site":',
#  ', "userType":',
#  ', "listPropertyType":',
#  ', "listBrokerage":',
#  ', "listVideo":',
#  ', "listDaysMarket":',
#  ', "listStatus":',
#  ', "cookie_q_c":',
#  ', "listNabe":',
#  ', "listBoro":',
#  ', "pageCat":',
#  ', "listAgent":',
# ...

# %%
myset = set(fields)

# %%
myset
# Out:
# {', "cookie_q_c":',
#  ', "listAgent":',
#  ', "listAmen":',
#  ', "listAvailDate":',
#  ', "listBath":',
#  ', "listBed":',
#  ', "listBoro":',
#  ', "listBrokerage":',
#  ', "listBuilding":',
#  ', "listDate":',
#  ', "listDaysMarket":',
#  ', "listFloor3d":',
#  ', "listFloorPlan":',
#  ', "listGeoLat":',
#  ', "listGeoLon":',
#  ', "listID":',
#  ', "listNabe":',
#  ', "listNoFee":',
#  ', "listPPSF":',
#  ', "listPhotos":',
#  ', "listPrice":',
#  ', "listPropertyType":',
#  ', "listRoom":',
#  ', "listSqFt":',
#  ', "listStatus":',
#  ', "listTaxAbate":',
#  ', "listType":',
#  ', "listVideo":',
#  ', "listZip":',
#  ', "pageCat":',
#  ', "pageType":',
#  ', "session_q_c":',
#  ', "site":',
#  ', "userType":'}
