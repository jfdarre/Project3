# %%
import sqlalchemy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://nycrex:admin@localhost:5432/nycrex')

# %%
df = pd.read_sql_query('select * from public.listings', con = engine)

# %%
df
# Out:
#           lID                                              title  \
# 0     1636645            97-45 Queens Blvd. in Rego Park, Queens
# 1     1663478        43-10 Crescent St. in Hunters Point, Queens
# 2     1663559                48-30 40th St. in Sunnyside, Queens
# 3     1663585                  20-24 31st St. in Astoria, Queens
# 4     1663595      37-33 College Point Blvd. in Flushing, Queens
# 5     1663597             16439 87th St. in Howard Beach, Queens
# 6     1663598              135-23 82nd Ave. in Briarwood, Queens
# 7     1663610            173-34 104th Ave. in St. Albans, Queens
# 8     1663623     34-59 Vernon Blvd. in Long Island City, Queens
# 9     1663631               87-30 62nd Ave. in Rego Park, Queens
# 10    1663637                   2430 43rd St. in Astoria, Queens
# 11    1663653  182-30 Wexford Terrace in Jamaica Estates, Queens
# 12    1662145               45-22 43rd Ave. in Sunnyside, Queens
# ...
